# %%
import json
import pandas as pd
from sqlalchemy import create_engine
from login_info import *

# %%
connection_string = "{}:{}@localhost:5432/crime_db".format(username, password)
engine = create_engine(f'postgresql://{connection_string}')

# %%
suburbs_data = "Suburbs_Lat_lng.csv"

# %%
suburbs_data = pd.read_csv(suburbs_data)
suburbs_data
# Out:
#      Suburb/Town Name                 LGA        Lat         Lng
# 0            Dederang              Alpine -36.473881  147.017504
# 1          Glen Creek              Alpine -36.441280  146.935870
# 2          Gundowring              Alpine -36.347993  147.075251
# 3     Kergunyah South              Alpine -36.426842  147.036163
# 4      Mongans Bridge              Alpine -36.589659  147.100327
# ...               ...                 ...        ...         ...
# 2825  Vite Vite North         Corangamite -37.771024  143.198864
# 2826     Tabberabbera      East Gippsland -37.548016  147.401422
# 2827      Clover Flat  Southern Grampians -37.599910  141.552799
# 2828     Tarrayoukyan  Southern Grampians -37.294629  141.615112
# 2829          Miowera          Wellington -37.480031  147.152593
#
# [2830 rows x 4 columns]

# %%
engine.table_names()
# Out:
# ['location', 'crime', 'local_gov_area']

# %%
suburbs_data = suburbs_data.rename(columns={"Suburb/Town Name": "suburb", "LGA": "lga", "Lat":"latitude", "Lng": "longitude"})
suburbs_data
# Out:
#                suburb                 lga   latitude   longitude
# 0            Dederang              Alpine -36.473881  147.017504
# 1          Glen Creek              Alpine -36.441280  146.935870
# 2          Gundowring              Alpine -36.347993  147.075251
# 3     Kergunyah South              Alpine -36.426842  147.036163
# 4      Mongans Bridge              Alpine -36.589659  147.100327
# ...               ...                 ...        ...         ...
# 2825  Vite Vite North         Corangamite -37.771024  143.198864
# 2826     Tabberabbera      East Gippsland -37.548016  147.401422
# 2827      Clover Flat  Southern Grampians -37.599910  141.552799
# 2828     Tarrayoukyan  Southern Grampians -37.294629  141.615112
# 2829          Miowera          Wellington -37.480031  147.152593
#
# [2830 rows x 4 columns]

# %%
suburbs_data = suburbs_data.dropna(how="any")
suburbs_data
# Out:
#                suburb                 lga   latitude   longitude
# 0            Dederang              Alpine -36.473881  147.017504
# 1          Glen Creek              Alpine -36.441280  146.935870
# 2          Gundowring              Alpine -36.347993  147.075251
# 3     Kergunyah South              Alpine -36.426842  147.036163
# 4      Mongans Bridge              Alpine -36.589659  147.100327
# ...               ...                 ...        ...         ...
# 2825  Vite Vite North         Corangamite -37.771024  143.198864
# 2826     Tabberabbera      East Gippsland -37.548016  147.401422
# 2827      Clover Flat  Southern Grampians -37.599910  141.552799
# 2828     Tarrayoukyan  Southern Grampians -37.294629  141.615112
# 2829          Miowera          Wellington -37.480031  147.152593
#
# [2829 rows x 4 columns]

# %%
suburbs_data.to_sql(name='location', con=engine, if_exists='append', index=False)

# %%
crime_data = "Criminal_incidents.csv"

# %%
crime_data = pd.read_csv(crime_data)

# %%
crime_data.head()
# Out:
#    Year Year ending Local Government Area  Postcode Suburb/Town Name  \
# 0  2021       March                Alpine      3691         Dederang
# 1  2021       March                Alpine      3691       Glen Creek
# 2  2021       March                Alpine      3691       Gundowring
# 3  2021       March                Alpine      3691       Gundowring
# 4  2021       March                Alpine      3691  Kergunyah South
#
#                     Offence Division               Offence Subdivision  \
# 0        A Crimes against the person  A20 Assault and related offences
# 1                    C Drug offences       C30 Drug use and possession
# 2                    C Drug offences  C10 Drug dealing and trafficking
# 3      E Justice procedures offences            E10 Justice procedures
# 4  B Property and deception offences                         B40 Theft
#
#                Offence Subgroup Incidents Recorded  Unnamed: 9
# 0       A211 FV Serious assault                  1         NaN
# 1           C32 Drug possession                  1         NaN
# 2          C12 Drug trafficking                  1         NaN
# 3  E13 Resist or hinder officer                  1         NaN
# 4               B49 Other theft                  1         NaN

# %%
crime_df = crime_data.drop(columns=["Year ending", "Offence Subgroup", "Unnamed: 9"])

# %%
crime_df.index.name = "index_no"
crime_df
# Out:
#           Year Local Government Area  Postcode Suburb/Town Name  \
# index_no
# 0         2021                Alpine      3691         Dederang
# 1         2021                Alpine      3691       Glen Creek
# 2         2021                Alpine      3691       Gundowring
# 3         2021                Alpine      3691       Gundowring
# 4         2021                Alpine      3691  Kergunyah South
# ...        ...                   ...       ...              ...
# 319368    2012          Yarriambiack      3487        Lascelles
# 319369    2012          Yarriambiack      3488            Speed
# 319370    2012          Yarriambiack      3489            Tempy
# 319371    2012          Yarriambiack      3489            Tempy
# 319372    2012          Yarriambiack      3491    Patchewollock
#
#                            Offence Division  \
# index_no
# 0               A Crimes against the person
# 1                           C Drug offences
# 2                           C Drug offences
# 3             E Justice procedures offences
# 4         B Property and deception offences
# ...                                     ...
# 319368    B Property and deception offences
# 319369    B Property and deception offences
# 319370          A Crimes against the person
# 319371          A Crimes against the person
# 319372          A Crimes against the person
#
#                                         Offence Subdivision Incidents Recorded
# index_no
# 0                          A20 Assault and related offences                  1
# 1                               C30 Drug use and possession                  1
# 2                          C10 Drug dealing and trafficking                  1
# 3                                    E10 Justice procedures                  1
# 4                                                 B40 Theft                  1
# ...                                                     ...                ...
# 319368                                        B50 Deception                  1
# 319369                                            B40 Theft                  2
# 319370                     A20 Assault and related offences                  1
# 319371    A70 Stalking, harassment and threatening behav...                  1
# 319372                      Other crimes against the person                  3
#
# [319373 rows x 7 columns]

# %%
crime_df = crime_df.rename(columns={"Year":"year","Suburb/Town Name": "suburb", "Postcode":"postcode", "Local Government Area": "lga", "Offence Division": "offence_div",
                                   "Offence Subdivision":"offence_sub_div", "Incidents Recorded": "incidents"})

# %%
crime_df = crime_df[["year", "suburb", "lga", "postcode", "offence_div", "offence_sub_div", "incidents"]]

# %%
crime_df.head()
# Out:
#           year           suburb     lga  postcode  \
# index_no
# 0         2021         Dederang  Alpine      3691
# 1         2021       Glen Creek  Alpine      3691
# 2         2021       Gundowring  Alpine      3691
# 3         2021       Gundowring  Alpine      3691
# 4         2021  Kergunyah South  Alpine      3691
#
#                                 offence_div                   offence_sub_div  \
# index_no
# 0               A Crimes against the person  A20 Assault and related offences
# 1                           C Drug offences       C30 Drug use and possession
# 2                           C Drug offences  C10 Drug dealing and trafficking
# 3             E Justice procedures offences            E10 Justice procedures
# 4         B Property and deception offences                         B40 Theft
#
#          incidents
# index_no
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1

# %%
crime_df = crime_df.dropna(how="any")
crime_df.head()
# Out:
#           year           suburb     lga  postcode  \
# index_no
# 0         2021         Dederang  Alpine      3691
# 1         2021       Glen Creek  Alpine      3691
# 2         2021       Gundowring  Alpine      3691
# 3         2021       Gundowring  Alpine      3691
# 4         2021  Kergunyah South  Alpine      3691
#
#                                 offence_div                   offence_sub_div  \
# index_no
# 0               A Crimes against the person  A20 Assault and related offences
# 1                           C Drug offences       C30 Drug use and possession
# 2                           C Drug offences  C10 Drug dealing and trafficking
# 3             E Justice procedures offences            E10 Justice procedures
# 4         B Property and deception offences                         B40 Theft
#
#          incidents
# index_no
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1

# %%
crime_df.replace(',','', regex=True, inplace=True)
crime_df[["year", "postcode", "incidents"]] = crime_df[["year", "postcode", "incidents"]].apply(pd.to_numeric)

# %%
lyons_loc = crime_df.loc[crime_df["suburb"] == "Lyons"].index
lyons_loc
# Out:
# Int64Index([44750, 78449, 112062, 241530, 241531, 271605], dtype='int64', name='index_no')

# %%
crime_df = crime_df.drop(lyons_loc)

# %%
crime_df.to_sql(name='crime', con=engine, if_exists='append', index=True)
