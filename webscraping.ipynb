chrome%20pdf%20plugin%3Bchrome%20pdf%20viewer%3Bnative%20client&amp;v77=D%3Dmid&amp;v78=au%7Cvic%7Cmelbourne%7C-37.82%7C144.97%7Cgmt%2B10%7Ctelstra&amp;v79=au&amp;v80=8f2f4d033a7d858aa867b2ad6196a493-00000000000000000000000000000000-1631180266140-935115&amp;v111=0&amp;v161=61.19999998807907&amp;s=1366x768&amp;c=24&amp;j=1.6&amp;v=N&amp;k=Y&amp;bw=1034&amp;bh=576&amp;mcorgid=5FE61C8B533204850A490D4D%40AdobeOrg&amp;AQE=1" type="text/javascript">
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="True" name="HandheldFriendly"/>
#   <meta content="320" name="MobileOptimized"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="noarchive" name="robots"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <meta content="news" name="application-name"/>
#   <meta content="GWTbDFKaKnGKyk3q0Na5jIbWHZ4qXn-ibcfMayjSQA0" name="google-site-verification"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="From local crime in your area to the latest police updates, news.com.au has you covered. Find all the breaking news related to crime and courts in Victoria." name="description"/>
#   <meta content="113758722003364" property="fb:app_id"/>
#   <link as="font" crossorigin="crossorigin" href="https://resourcesssl.newscdn.com.au/cs/ts2020/assets/fonts/eva-bold.woff2" rel="preload" type="font/woff2"/>
#   <title>
#    VIC Crime | Victoria Courts News &amp; Latest Updates | news.com.au — Australia’s leading news site
#   </title>
#   <link href="https://tags.tiqcdn.com/" rel="dns-prefetch"/>
#   <link href="https://nca.talk.news.com.au/" rel="dns-prefetch"/>
#   <link href="https://tags.news.com.au/" rel="dns-prefetch"/>
#   <link href="https://metrics.news.com.au/" rel="dns-prefetch"/>
#   <link href="https://www.news.com.au/wp-content/themes/newscorpau-news-dna/dist/javascripts/manifest-news.json" rel="manifest"/>
#   <link as="style" href="https://www.news.com.au/wp-content/themes/newscorpau-news-dna/dist/stylesheets/css-news-desktop-lazy.css" rel="preload"/>
#   <link href="https://www.news.com.au/wp-content/themes/newscorpau-news-dna/dist/images/favicons/news-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="https://www.news.com.au/wp-content/themes/newscorpau-news-dna/dist/images/favicons/news-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="https://www.news.com.au/wp-content/themes/newscorpau-news-dna/dist/images/apple-touch-icons/news-apple-touch-icon.png" rel="apple-touch-icon"/>
#   <!-- Lux (1 every  1 visits) -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-3922003-31&amp;l=dataLayer&amp;cx=c" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-31428401-1&amp;l=dataLayer&amp;cx=c" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googleadservices.com/pagead/conversion_async.js" type="text/javascript">
#   </script>
#   <script async="" src="https://script.crazyegg.com/pages/versioned/common-scripts/11.1.331.js" type="text/javascript">
#   </script>
#   <script async="" data-jsonpid="" src="https://cdn-gl.imrworldwide.com/novms/js/2/nlsSDK600.bundle.min.js">
#   </script>
#   <script src="https://cdn.adsafeprotected.com/iasPET.1.js" type="text/javascript">
#   </script>
#   <script async="" src="https://cdn-gl.imrworldwide.com/conf/PA29B4FFF-94A8-4A65-AA29-3329DFE3AEC3.js#name=__ni0&amp;ns=NOLBUNDLE">
#   </script>
#   <script async="" src="https://lps.qantas.com/sp.js">
#   </script>
#   <script async="" charset="utf-8" id="utag_305" src="https://www.googletagmanager.com/gtag/js?id=AW-970140527" type="text/javascript">
#   </script>
#   <script async="" id="tealium-tag-3005" src="https://sb.scorecardresearch.com/c2/6390601/cs.js" type="text/javascript">
#   </script>
#   <script async="" src="https://connect.facebook.net/signals/config/285633425101545?v=2.9.45&amp;r=stable">
#   </script>
#   <script async="" charset="utf-8" id="utag_303" src="https://connect.facebook.net/en_US/fbevents.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" id="utag_190" src="//tags.news.com.au/prod/metrics/metrics.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" id="utag_155" src="https://tags.news.com.au/prod/nielsen/nielsen.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" id="utag_5" src="//ats.rlcdn.com/ats.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" id="utag_5" src="//tags.news.com.au/prod/prebid/prebid.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" id="utag_5" src="//securepubads.g.doubleclick.net/tag/js/gpt.js" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" id="utag_5" src="//tags.news.com.au/prod/tad/tad.js" type="text/javascript">
#   </script>
#   <script async="" src="//tags.news.com.au/prod/mitas/mitas.js" type="text/javascript">
#   </script>
#   <script>
#    LUX=(function(){var a=("undefined"!==typeof(LUX)&&"undefined"!==typeof(LUX.gaMarks)?LUX.gaMarks:[]);var d=("undefined"!==typeof(LUX)&&"undefined"!==typeof(LUX.gaMeasures)?LUX.gaMeasures:[]);var j="LUX_start";var k=window.performance;var l=("undefined"!==typeof(LUX)&&LUX.ns?LUX.ns:(Date.now?Date.now():+(new Date())));if(k&&k.timing&&k.timing.navigationStart){l=k.timing.navigationStart}function f(){if(k&&k.now){return k.now()}var o=Date.now?Date.now():+(new Date());return o-l}function b(n){if(k){if(k.mark){return k.mark(n)}else{if(k.webkitMark){return k.webkitMark(n)}}}a.push({name:n,entryType:"mark",startTime:f(),duration:0});return}function m(p,t,n){if("undefined"===typeof(t)&&h(j)){t=j}if(k){if(k.measure){if(t){if(n){return k.measure(p,t,n)}else{return k.measure(p,t)}}else{return k.measure(p)}}else{if(k.webkitMeasure){return k.webkitMeasure(p,t,n)}}}var r=0,o=f();if(t){var s=h(t);if(s){r=s.startTime}else{if(k&&k.timing&&k.timing[t]){r=k.timing[t]-k.timing.navigationStart}else{return}}}if(n){var q=h(n);if(q){o=q.startTime}else{if(k&&k.timing&&k.timing[n]){o=k.timing[n]-k.timing.navigationStart}else{return}}}d.push({name:p,entryType:"measure",startTime:r,duration:(o-r)});return}function h(n){return c(n,g())}function c(p,o){for(i=o.length-1;i>=0;i--){var n=o[i];if(p===n.name){return n}}return undefined}function g(){if(k){if(k.getEntriesByType){return k.getEntriesByType("mark")}else{if(k.webkitGetEntriesByType){return k.webkitGetEntriesByType("mark")}}}return a}return{mark:b,measure:m,gaMarks:a,gaMeasures:d}})();LUX.ns=(Date.now?Date.now():+(new Date()));LUX.ac=[];LUX.cmd=function(a){LUX.ac.push(a)};LUX.init=function(){LUX.cmd(["init"])};LUX.send=function(){LUX.cmd(["send"])};LUX.addData=function(a,b){LUX.cmd(["addData",a,b])};LUX_ae=[];window.addEventListener("error",function(a){LUX_ae.push(a)});LUX_al=[];if("function"===typeof(PerformanceObserver)&&"function"===typeof(PerformanceLongTaskTiming)){var LongTaskObserver=new PerformanceObserver(function(c){var b=c.getEntries();for(var a=0;a<b.length;a++){var d=b[a];LUX_al.push(d)}});try{LongTaskObserver.observe({type:["longtask"]})}catch(e){}};
#   </script>
#   <script async="async" crossorigin="anonymous" defer="defer" src="https://cdn.speedcurve.com/js/lux.js?id=338391603">
#   </script>
#   <script>
#    LUX = window.LUX || {};
# LUX.label = "Index";
#   </script>
#   <script id="newscorpau-vars">
#    var newscorpau = newscorpau || {};
# newscorpau.site = "news";
# newscorpau.device = "desktop";
# newscorpau.pagetype = "index";
# newscorpau.environment = "prod";
# newscorpau.disableAuth = false;
# newscorpau.disablePaywall = false;
# newscorpau.disableSearch = false;
# newscorpau.disableWeather = false;
#
#
# newscorpau.subscribeUrl = "https://www.news.com.au/subscribe/news/1/?int_medium=display&int_source=site-link&int_campaign=acq_onsite_login&int_content=link&sourceCode=";
# newscorpau.sourceCodeMap = "NW";
# newscorpau.coralcomments = {};
# newscorpau.coralcomments.url = "https://nca.talk.news.com.au/static/embed.js";
# newscorpau.coralcomments.talk = "https://nca.talk.news.com.au";
# newscorpau.c3po = {};
# newscorpau.c3po.enabled = false;
# newscorpau.isMetro = "false";
#   </script>
#   <script>
#    const isiPad = (navigator.platform === 'MacIntel' && navigator.maxTouchPoints > 1);
# if (isiPad) {
#     document.querySelector('html').setAttribute('data-device-type', 'ipad');
#
#     //- Changing call to a relative link because beta URLs are causing problems.
#     let siteURL = '';
#     //let siteURL = `https://www.${newscorpau.site}${newscorpau.environment === 'prod' ? '' : newscorpau.environment}.com.au`;
#     //- if (newscorpau.environment === 'local') {
#     //-     siteURL = `http://${newscorpau.site}.local`;
#     //- }
#
#     fetch(`${siteURL}/spp-api/v1/template/?path=layouts.whitelabel.mobile-nav&render=phug`)
#     .then(response => {
#         return response.text();
#     })
#     .then(text => {
#         let navCSS = document.createElement('link');
#         navCSS.setAttribute('rel', 'stylesheet');
#         navCSS.setAttribute('href', `${siteURL}/wp-content/themes/newscorpau-news-dna/dist/stylesheets/css-mobile-nav.css`);
#         document.head.appendChild(navCSS);
#         let nav = document.createElement('div');
#         nav.innerHTML = text;
#         document.body.appendChild(nav);
#     })
#     .then(() => {
#         let hamburger = `<div class="hamburger"><div class="icon-sprite-item" style="width: 16px; height: 16px"><svg><use xlink:href="#hamburger"></use></svg></div><div class="icon-sprite-item" style="width: 16px; height: 16px"><svg><use xlink:href="#cross"></use></svg></div></div>`;
#         document.querySelector('nav.navigation').innerHTML += hamburger;
#         let backdrop = document.createElement('div');
#         backdrop.classList.add('backdrop');
#         document.body.appendChild(backdrop);
#         let navJS = document.createElement('script');
#         navJS.setAttribute('src', `${siteURL}/wp-content/themes/newscorpau-news-dna/dist/javascripts/js-navigation-mobile.js`);
#         document.head.appendChild(navJS);
#     });
#
# }
#   </script>
#   <style>
#    @font-face{font-family:"Eva Bold";src:url("https://resourcesssl.newscdn.com.au/cs/ts2020/assets/fonts/eva-bold.woff2") format("woff2");font-style:normal;font-weight:normal;-webkit-font-smoothing:antialiased;font-display:swap}/*! normalize.css v8.0.1 | MIT License | github.com/necolas/normalize.css */html,body,blockquote,h1,h2,h3,h4,h5,h6,p,ol,ul{margin:0;padding:0;border:0;font:inherit;font-size:100%;vertical-align:baseline}ol,ul{list-style:none}html{line-height:1.15;-webkit-text-size-adjust:100%;box-sizing:border-box;font-size:16px}@media (max-width: 1007px) and (min-width: 600px){html{font-size:12px}}@media (max-width: 600px){html{font-size:8px}}body{margin:0}main{display:block}hr{box-sizing:content-box;height:0;overflow:visible}pre{font-family:monospace;font-size:1em}a{background-color:transparent;color:#202223;text-decoration:none}a:hover{text-decoration:underline}abbr[title]{border-bottom:none;text-decoration:underline;text-decoration:underline dotted}b,strong{font-weight:bolder}code,kbd,samp{font-family:monospace;font-size:1em}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sub{bottom:-0.25em}sup{top:-0.5em}img{border-style:none;text-indent:-9999px;white-space:nowrap;overflow:hidden}button,input,optgroup,select,textarea{font-family:inherit;font-size:100%;line-height:1.15;margin:0}button,input{overflow:visible}button,select{text-transform:none}[type=button],[type=reset],[type=submit],button{-webkit-appearance:button}[type=button]::-moz-focus-inner,[type=reset]::-moz-focus-inner,[type=submit]::-moz-focus-inner,button::-moz-focus-inner{border-style:none;padding:0}[type=button]:-moz-focusring,[type=reset]:-moz-focusring,[type=submit]:-moz-focusring,button:-moz-focusring{outline:1px dotted ButtonText}fieldset{padding:0.35em 0.75em 0.625em}legend{box-sizing:border-box;color:inherit;display:table;max-width:100%;padding:0;white-space:normal}progress{vertical-align:baseline}textarea{overflow:auto}[type=checkbox],[type=radio]{box-sizing:border-box;padding:0}[type=number]::-webkit-inner-spin-button,[type=number]::-webkit-outer-spin-button{height:auto}[type=search]{-webkit-appearance:textfield;outline-offset:-2px}[type=search]::-webkit-search-decoration{-webkit-appearance:none}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}details{display:block}summary{display:list-item}template{display:none}[hidden]{display:none}*,*::before,*::after{box-sizing:inherit}.g_font-title-xxxs{font:400 16px/1.3 "Eva Bold","Times New Roman",Times,serif}.g_font-title-xxs{font:400 18px/1.3 "Eva Bold","Times New Roman",Times,serif}.g_font-title-xs{font:400 calc(16px + 0.5rem)/1.3 "Eva Bold","Times New Roman",Times,serif}.g_font-title-s{font:400 calc(16px + 0.8rem)/1.3 "Eva Bold","Times New Roman",Times,serif}.g_font-title-m{font:400 calc(16px + 1rem)/1.3 "Eva Bold","Times New Roman",Times,serif}.g_font-title-l{font:400 calc(16px + 1.3rem)/1.3 "Eva Bold","Times New Roman",Times,serif}.g_font-title-xl{font:400 calc(16px + 2rem)/1.3 "Eva Bold","Times New Roman",Times,serif}.g_font-title-xxl{font:400 calc(16px + 2.5rem)/1.3 "Eva Bold","Times New Roman",Times,serif}.g_font-base-xs{font:normal calc(16px + -0.5rem)/1.3 "Helvetica Neue",HelveticaNeue,Helvetica,Arial,sans-serif}.g_font-base-s{font:normal calc(16px + -0.25rem)/1.3 "Helvetica Neue",HelveticaNeue,Helvetica,Arial,sans-serif}.g_font-base-m{font:normal 16px/1.3 "Helvetica Neue",HelveticaNeue,Helvetica,Arial,sans-serif}.g_font-base-l{font:normal 24px/1.3 "Helvetica Neue",HelveticaNeue,Helvetica,Arial,sans-serif}.g_font-body-s{font:normal 14px/1.3 "Helvetica Neue",HelveticaNeue,Helvetica,Arial,sans-serif}.g_font-body-m{font:normal 16px/1.3 "Helvetica Neue",HelveticaNeue,Helvetica,Arial,sans-serif}.g_font-body-l{font:normal 18px/1.3 "Helvetica Neue",HelveticaNeue,Helvetica,Arial,sans-serif}.g_font-long-format{font:normal 18px/1.5 "Helvetica Neue",HelveticaNeue,Helvetica,Arial,sans-serif}.page-title{margin:16px 0}.g_wrapper{margin:0 auto; ...
#
#
# /*# sourceMappingURL=css-news-desktop-critical-index.css.map*/
#   </style>
#   <!--  wp_head start -->
#   <!--  wp_head end
#  -->
#   <!-- top/all.esi prod 2020-09-23T01:46:46.630Z e2fd69d11987add3b48ba9e102d83569a487ee36 -->
#   <!--    url empty ?: 0   -->
#   <!--    ID:  No id found -->
#   <!--    ID_Type:  None -->
#   <!--    Is mobile: false -->
#   <script type="text/javascript">
#    window.utag_data = window.utag_data || {};
#     window.utag_data.newskey = "8f2f4d033a7d858aa867b2ad6196a493";
#     (function(){
#         var qs = location.search;
#         var pn = location.pathname;
#         qs=qs.replace(/\?nk=[^&]*&/,'?');
#         qs=qs.replace(/&nk=[^&]*&/g,'&');
#         qs=qs.replace(/&nk=.*$/,'');
#         qs=qs.replace(/\?nk=.*$/,'');
#         if (qs != location.search || pn != location.pathname) {
#             // Modern browsers, don't refresh, just get rid of the affecting parameters
#             if (window.history && history.replaceState) {
#                 history.replaceState({}, '', location.href.replace(location.pathname, pn).replace(location.search, qs));
#             }
#         }
#     })();
#   </script>
#   <script type="text/javascript">
#    window.utag_data = window.utag_data || {};
#     window.utag_data.backend_mobile_detect = false;
#     window.utag_data.backend_geo_country = "au";
#     window.utag_data.backend_geo_region = "vic";
#     window.utag_data.backend_geo_city = "melbourne";
#     window.utag_data.backend_geo_lat = "-37.82";
#     window.utag_data.backend_geo_long = "144.97";
#     window.utag_data.backend_geo_tmz = "gmt+10";
#     window.utag_data.backend_geo_network = "telstra";
#     window.utag_data.gdpr_user = false;
#   </script>
#   <script>
#    bruce_rtget={"sno":0,"snol":"","tmstamp":"2021-09-09T09:32:39.316Z"};
#   </script>
#   <!-- end of top/all.esi -->
#   <link href="https://www.news.com.au/wp-content/themes/newscorpau-news-dna/dist/stylesheets/css-news-desktop-lazy.css?v=15" rel="stylesheet"/>
#   <script async="" src="https://www.news.com.au/remote/identity/rampart/latest/rampart.js">
#   </script>
#   <script async="" src="https://www.news.com.au/wp-content/themes/newscorpau-news-dna/dist/javascripts/js-news-desktop-lazy.js?v=15">
#   </script>
#   <script async="" src="https://www.news.com.au/wp-content/themes/newscorpau-news-dna/dist/javascripts/js-weather.js?v=15">
#   </script>
#   <script async="" src="https://ts2020-indies-client.web.app/indies-loader.js">
#   </script>
#   <script async="" src="https://tags.tiqcdn.com/utag/newsltd/news/prod/utag.sync.js">
#   </script>
#   <script async="" src="https://tags.tiqcdn.com/utag/newsltd/news/prod/utag.js">
#   </script>
#   <script async="" src="https://www.news.com.au/wp-content/themes/newscorpau-news-dna/dist/javascripts/js-vidora-client.js?v=15">
#   </script>
#   <script async="" src="https://assets.vidora.com/js/vidora-client.1.x.x.min.js">
#   </script>
#   <script src="https://tags.news.com.au/prod/utrack/utrack.js?cb=16311802659490.9137225834745695" type="text/javascript">
#   </script>
#   <script src="//static.chartbeat.com/js/chartbeat_video.js">
#   </script>
#   <script async="" src="https://au.tags.newscgp.com/prod/ncg/ncg.js?v=2.14.0">
#   </script>
#   <script src="//script.crazyegg.com/pages/scripts/0018/2988.js">
#   </script>
#   <script async="" charset="utf-8" id="tiqapp" src="//tags.tiqcdn.com/utag/tiqapp/utag.v.js?a=newsltd/news/202109070405&amp;cb=1631180266066" type="text/javascript">
#   </script>
#   <meta content="A88otRz1Fd3Nt567e2IYshC18LL3KGVXpVJW9oTCId4RYaygt23pbb4JqrbdIO/bwZPWEmRjBIRBu/bZbDR7Pg4AAABueyJvcmlnaW4iOiJodHRwczovL2ltYXNkay5nb29nbGVhcGlzLmNvbTo0NDMiLCJmZWF0dXJlIjoiVHJ1c3RUb2tlbnMiLCJleHBpcnkiOjE2MzQwODMxOTksImlzVGhpcmRQYXJ0eSI6dHJ1ZX0=" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="A04ZCu7yjrHgwQJK5ISHhH1DSg0qqowEay3n70KO6wV3D2Mj+OX3Kw20aSMitzgdG1xfrN7sOJV/dZIk+RvCzA4AAAB2eyJvcmlnaW4iOiJodHRwczovL2dvb2dsZS5jb206NDQzIiwiZmVhdHVyZSI6IlRydXN0VG9rZW5zIiwiZXhwaXJ5IjoxNjM0MDgzMTk5LCJpc1N1YmRvbWFpbiI6dHJ1ZSwiaXNUaGlyZFBhcnR5Ijp0cnVlfQ==" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <script async="" src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_2021090201.js">
#   </script>
#   <script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/970140527/?random=1631180268046&amp;cv=9&amp;fst=1631180268046&amp;num=1&amp;bg=ffffff&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=768&amp;u_w=1366&amp;u_ah=728&amp;u_aw=1366&amp;u_cd=24&amp;u_his=2&amp;u_tz=600&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2oa910&amp;sendb=1&amp;ig=1&amp;data=event%3Dgtag.config&amp;frm=0&amp;url=https%3A%2F%2Fwww.news.com.au%2Fnational%2Fvictoria%2Fcrime&amp;tiba=VIC%20Crime%20%7C%20Victoria%20Courts%20News%20%26%20Latest%20Updates%20%7C%20news.com.au%20%E2%80%94%20Australia%E2%80%99s%20leading%20news%20site&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4">
#   </script>
#   <script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/970140527/?random=1631180268050&amp;cv=9&amp;fst=1631180268050&amp;num=1&amp;bg=ffffff&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=768&amp;u_w=1366&amp;u_ah=728&amp;u_aw=1366&amp;u_cd=24&amp;u_his=2&amp;u_tz=600&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2oa910&amp;sendb=1&amp;ig=1&amp;data=event%3Dpage_view&amp;frm=0&amp;url=https%3A%2F%2Fwww.news.com.au%2Fnational%2Fvictoria%2Fcrime&amp;tiba=VIC%20Crime%20%7C%20Victoria%20Courts%20News%20%26%20Latest%20Updates%20%7C%20news.com.au%20%E2%80%94%20Australia%E2%80%99s%20leading%20news%20site&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4">
#   </script>
#   <script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/970140527/?random=1631180268091&amp;cv=9&amp;fst=1631180268091&amp;num=1&amp;bg=ffffff&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h
#       </path>
#      </symbol>
#      <symbol id="libra" viewbox="0 0 24 24">
#       <path d="M23.04 19v2.095H1V19h22.04zM12.02 3c4.154 0 7.358 3.201 7.358 7.354 0 .99-.287 2.146-.851 3.484l-.1.228 4.612.001v2.095h-8.03l.819-1.54c.978-1.838 1.455-3.276 1.455-4.268 0-2.995-2.266-5.259-5.263-5.259s-5.26 2.263-5.26 5.26c0 .904.435 2.209 1.328 3.871l.173.316.867 1.557H1v-2.095h4.637l-.088-.196c-.538-1.216-.833-2.28-.878-3.205l-.006-.249C4.665 6.201 7.865 3 12.02 3z">
#       </path>
#      </symbol>
#      <symbol id="location" viewbox="0 0 16 16">
#       <path d="M8.003 7a2 2 0 11.001-4.001A2 2 0 018.003 7m4.475-4.266C11.24.292 8.237-.698 5.767.523 3.296 1.744 2.294 4.714 3.529 7.156L8.003 16l4.475-8.844a4.942 4.942 0 000-4.422" fill="#606669" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="magnifier" viewbox="0 0 16 16">
#       <path d="M6 0a6 6 0 014.885 9.485L15.3 13.9a.99.99 0 11-1.4 1.4l-4.415-4.415A6 6 0 116 0zm0 2a4 4 0 100 8 4 4 0 000-8z" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="notificationBell" viewbox="0 0 14 16">
#       <path d="M9 14a2 2 0 01-4 0zM8 0v1.125c2.331.486 4 2.655 4 5.09V11l2 2H0l2-2V6a4.999 4.999 0 014-4.895V0h2z" fill="#C90000" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="pisces" viewbox="0 0 24 24">
#       <path d="M8.672 13.072C8.436 16.339 7.04 19.652 4.508 23l-1.74-1.315.296-.4c2.061-2.833 3.193-5.57 3.42-8.214H2V10.89h4.466C6.188 8.164 4.96 5.298 2.758 2.288L4.518 1l.303.422c2.285 3.233 3.571 6.39 3.836 9.468h7.532c.264-3.077 1.55-6.235 3.836-9.468L20.328 1l1.76 1.288c-2.203 3.01-3.43 5.876-3.708 8.602h3.63v2.181h-3.648c.227 2.645 1.359 5.38 3.42 8.214l.296.4L20.338 23c-2.53-3.349-3.929-6.661-4.164-9.928z">
#       </path>
#      </symbol>
#      <symbol id="play" viewbox="0 0 16 16">
#       <path d="M3 1l13 7-13 7z" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="plus" viewbox="0 0 16 16">
#       <path d="M8 0a8 8 0 110 16A8 8 0 018 0zm0 3a1 1 0 00-1 1v3H4a1 1 0 000 2h3v3a1 1 0 002 0V9h3a1 1 0 000-2H9V4a1 1 0 00-1-1z" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="premium" viewbox="0 0 16 16">
#       <g fill="none" fill-rule="evenodd">
#        <path d="M5.333 5.333h5.333v5.333H5.333z" fill="#A771A3">
#        </path>
#        <path d="M5.333 10.667h5.334v4L9.333 16h-4z" fill="#D8127D">
#        </path>
#        <path d="M0 6.667l1.333-1.334h4v5.334H0z" fill="#B9D137">
#        </path>
#        <path d="M6.667 0h4v5.333H5.333v-4z" fill="#00A3DA">
#        </path>
#        <path d="M19.172 16.555h-2.317V24.5h-3.31v-7.945H12v-2.869h1.545V11.81c0-1.324.662-3.31 3.42-3.31h2.538v2.759h-1.765c-.331 0-.662.11-.662.772v1.655h2.538l-.442 2.87z">
#        </path>
#       </g>
#      </symbol>
#      <symbol id="social-instagram" viewbox="0 0 16 16">
#       <path d="M11 1a4 4 0 014 4v6a4 4 0 01-4 4H5a4 4 0 01-4-4V5a4 4 0 014-4zm0 1.5H5A2.503 2.503 0 002.5 5v6c0 1.379 1.122 2.5 2.5 2.5h6c1.378 0 2.5-1.121 2.5-2.5V5c0-1.379-1.122-2.5-2.5-2.5zm-3 2a3.5 3.5 0 110 7 3.5 3.5 0 010-7zM8 6c-1.103 0-2 .897-2 2s.897 2 2 2 2-.897 2-2-.897-2-2-2zm3.5-2.5a1 1 0 110 2 1 1 0 010-2z" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="social-tiktok" viewbox="0 0 3333 3333">
#       <path d="M1667 0c920 0 1667 746 1667 1667 0 920-746 1667-1667 1667C747 3334 0 2588 0 1667 0 747 746 0 1667 0zm361 744c31 262 177 418 430 434v294c-147 14-276-34-426-124v550c0 700-763 918-1069 417-197-322-76-889 556-911v311c-48 8-99 20-146 36-141 47-220 137-198 294 43 301 595 390 549-198V745h305z" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="social-twitter" viewbox="0 0 16 16">
#       <path d="M16 3.563c-.6.25-1.2.453-1.9.502a3.47 3.47 0 001.45-1.814c-.65.353-1.35.657-2.1.808A3.236 3.236 0 0011.05 2C9.25 2 7.8 3.46 7.8 5.276c0 .252.05.503.1.756-2.7-.152-5.1-1.463-6.75-3.428-.3.504-.45 1.06-.45 1.663 0 1.16.6 2.167 1.45 2.721-.55 0-1.05-.152-1.5-.404v.052a3.295 3.295 0 002.6 3.224c-.25.1-.55.1-.85.1-.2 0-.4 0-.6-.049.4 1.31 1.6 2.268 3.05 2.268-1.1.905-2.55 1.41-4.05 1.41-.25 0-.5 0-.8-.05 1.45.957 3.15 1.462 5 1.462 6 0 9.3-5.04 9.3-9.373v-.404c.7-.402 1.25-1.008 1.7-1.662" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="social-whatsapp" viewbox="0 0 16 16">
# ...
#          </li>
#          <li class="footer_menu_item_sub">
#           <a href="/in-the-know-quiz/dashboard">
#            In The Know Quiz
#           </a>
#          </li>
#          <li class="footer_menu_item_sub">
#           <a data-tgev="event10" data-tgev-container="global-sign-in" data-tgev-label="newsletter" data-tgev-metric="ev" data-tgev-order="5" href="https://www.newsletters.news.com.au/nca">
#            Newsletters
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="footer_menu_item">
#         <h4 class="footer_menu_item_title g_font-body-s">
#          About us
#         </h4>
#         <ul class="footer_menu_nav_sub">
#          <li class="footer_menu_item_sub">
#           <a href="/help">
#            Welcome to news.com.au
#           </a>
#          </li>
#          <li class="footer_menu_item_sub">
#           <a href="/the-team">
#            The Team
#           </a>
#          </li>
#          <li class="footer_menu_item_sub">
#           <a href="/help#our-values">
#            Our Values
#           </a>
#          </li>
#          <li class="footer_menu_item_sub">
#           <a href="/help/code-of-conduct">
#            Code of Conduct
#           </a>
#          </li>
#          <li class="footer_menu_item_sub">
#           <a href="https://www.news.com.au/best-of">
#            Shopping
#           </a>
#          </li>
#          <li class="footer_menu_item_sub">
#           <a href="https://www.news.com.au/coupons">
#            Coupons
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="footer_menu_item">
#         <h4 class="footer_menu_item_title g_font-body-s">
#          Help &amp; Support
#         </h4>
#         <ul class="footer_menu_nav_sub">
#          <li class="footer_menu_item_sub">
#           <a href="/help#contact-us">
#            Contact us
#           </a>
#          </li>
#          <li class="footer_menu_item_sub">
#           <a href="/help/faqs">
#            FAQ
#           </a>
#          </li>
#          <li class="footer_menu_item_sub">
#           <a href="/help#reader-help">
#            General Feedback
#           </a>
#          </li>
#          <li class="footer_menu_item_sub">
#           <a href="https://www.newscorpaustralia.com/brand/newscomau/">
#            Advertise with us
#           </a>
#          </li>
#          <li class="footer_menu_item_sub">
#           <a href="/help/site-map">
#            Site Map
#           </a>
#          </li>
#          <li class="footer_menu_item_sub">
#           <a href="https://form.123formbuilder.com/5838955/News-Corp-Copyright-And-Licensing-Inquiry-Form">
#            Content Licensing
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="footer_menu_item">
#         <h4 class="footer_menu_item_title g_font-body-s">
#          Our News Network
#         </h4>
#         <ul class="footer_menu_nav_sub">
#          <li class="footer_menu_item_sub">
#           <a href="https://www.kidsnews.com.au/">
#            Kids News
#           </a>
#          </li>
#          <li class="footer_menu_item_sub">
#           <a href="https://www.dailytelegraph.com.au/">
#            The Daily Telegraph
#           </a>
#          </li>
#          <li class="footer_menu_item_sub">
#           <a href="https://www.heraldsun.com.au/">
#            Herald Sun
#           </a>
#          </li>
#          <li class="footer_menu_item_sub">
#           <a href="https://www.couriermail.com.au/">
#            The Courier Mail
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="footer_menu_item">
#         <h4 class="footer_menu_item_title g_font-body-s">
#          Our Partners
#         </h4>
#         <ul class="footer_menu_nav_sub">
#          <li class="footer_menu_item_sub">
#           <a href="https://www.kidspot.com.au/">
#            Kidspot
#           </a>
#          </li>
#          <li class="footer_menu_item_sub">
#           <a href="https://www.bodyandsoul.com.au/">
#            Body+Soul
#           </a>
#          </li>
#          <li class="footer_menu_item_sub">
#           <a href="https://www.realestate.com.au/buy?rsf=syn:news:nca:news:spa">
#            realestate.com.au
#           </a>
#          </li>
#          <li class="footer_menu_item_sub">
#           <a href="https://www.foxsports.com.au/">
#            FoxSports
#           </a>
#          </li>
#         </ul>
#        </li>
#       </ul>
#       <div class="footer_apps g_font-base-s">
#        <p class="footer_apps_title g_font-body-s">
#         Our Apps
#        </p>
#        <ul class="footer_apps_ul">
#         <li class="footer_apps_apple">
#          <a href="https://itunes.apple.com/au/app/news-com-au/id1454481155?mt=8&amp;ct=marketinglandingpage">
#           <div class="icon-sprite-item" style="width: 120px; height: 40px">
#            <svg>
#             <use xlink:href="#apps-apple">
#             </use>
#            </svg>
#           </div>
#          </a>
#         </li>
#         <li class="footer_apps_google">
#          <a href="https://play.google.com/store/apps/details?id=com.newscorp.newscomau.app&amp;referrer=utm_source%3Dmarketinglandingpage">
#           <svg height="40" width="135" xmlns="http://www.w3.org/2000/svg">
#            <defs>
#             <lineargradient id="a" x1="60.99%" x2="26.536%" y1="4.946%" y2="71.879%">
#              <stop offset="0%" stop-color="#00A0FF">
#              </stop>
#              <stop offset="1%" stop-color="#00A1FF">
#              </stop>
#              <stop offset="26%" stop-color="#00BEFF">
#              </stop>
#              <stop offset="51%" stop-color="#00D2FF">
#              </stop>
#              <stop offset="76%" stop-color="#00DFFF">
#              </stop>
#              <stop offset="100%" stop-color="#00E3FF">
#              </stop>
#             </lineargradient>
#             <lineargradient id="b" x1="107.685%" x2="-130.64%" y1="50%" y2="50%">
#              <stop offset="0%" stop-color="#FFE000">
#              </stop>
#              <stop offset="41%" stop-color="#FFBD00">
#              </stop>
#              <stop offset="78%" stop-color="orange">
#              </stop>
#              <stop offset="100%" stop-color="#FF9C00">
#              </stop>
#             </lineargradient>
#             <lineargradient id="c" x1="86.271%" x2="-50.18%" y1="30.873%" y2="136.109%">
#              <stop offset="0%" stop-color="#FF3A44">
#              </stop>
#              <stop offset="100%" stop-color="#C31162">
#              </stop>
#             </lineargradient>
#             <lineargradient id="d" x1="-18.825%" x2="42.086%" y1="-11.91%" y2="35.079%">
#              <stop offset="0%" stop-color="#32A071">
#              </stop>

#           </svg>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="footer_notes g_font-base-s">
#       <div class="footer_disclaimer_text">
#        <strong>
#         A NOTE ABOUT RELEVANT ADVERTISING:
#        </strong>
#        We collect information about the content (including ads) you use across this site and use it to make both advertising and content more relevant to you on our network and other sites.
#        <a href="https://preferences.news.com.au/##collect">
#         Find out more about our policy and your choices, including how to opt-out.
#        </a>
#       </div>
#       <ul class="footer_external_links">
#        <li class="footer_external-links_privacy">
#         <a href="https://preferences.news.com.au/">
#          Privacy policy
#         </a>
#        </li>
#        <li class="footer_external-links_opt-out">
#         <a href="https://preferences.news.com.au/##optout">
#          Relevant ads opt-out
#         </a>
#        </li>
#        <li class="footer_external-links_cookie-policy">
#         <a href="https://preferences.news.com.au/cookies">
#          Cookie policy
#         </a>
#        </li>
#        <li class="footer_external-links_terms-of-use">
#         <a href="/more-information/terms-and-conditions">
#          Terms of use
#         </a>
#        </li>
#       </ul>
#       <div class="footer_copyright">
#        <span class="footer_copyright_text">
#         Nationwide News Pty Ltd © 2021. All times AEST (GMT +10).
#        </span>
#        <span class="footer_poweredby_wordpress">
#         Powered by
#         <a href="https://vip.wordpress.com/" rel="nofollow">
#          WordPress.com VIP
#         </a>
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <!--  wp_footer start -->
#   <!--  wp_footer end
#  -->
#   <div id="stats">
#    <script>
#     utag_data                           = window.utag_data || {};
# utag_data.ad_sec1 = "news";
#
# utag_data.ad_sec2 = "national";
#
# utag_data.ad_sec3 = "victoria";
#
# utag_data.ad_sec4 = "crime";
#
#
#
# utag_data.ad_pagetype 				= "";
# utag_data.net_pn 					= "news.com.au — australia’s leading news site | national | index | vic crime";
# utag_data.net_platform				= "web";
# utag_data.net_sec1 = "national";
#
# utag_data.net_sec2 = "victoria";
#
# utag_data.net_sec3 = "crime";
#
#
#
# utag_data.net_template              = "1.0+theme_newscorpau_news_dna";
# utag_data.net_content_type 			= "index";
#
#
# utag_data.autorefresh 				= (window.newscorpau.pagetype === "homepage" && document.referrer === window.location.href) ? true : false;
#    </script>
#   </div>
#   <div id="resources">
#    <script>
#     newscorpau.rampartJS = "https://www.news.com.au/remote/identity/rampart/latest/rampart.js";
# newscorpau.utagSyncJS = "https://tags.tiqcdn.com/utag/newsltd/news/prod/utag.sync.js";
# newscorpau.utagJS = "https://tags.tiqcdn.com/utag/newsltd/news/prod/utag.js";
# newscorpau.siteJS = "https://www.news.com.au/wp-content/themes/newscorpau-news-dna/dist/javascripts/js-news-desktop-lazy.js?v=15";
# newscorpau.siteCSS = "https://www.news.com.au/wp-content/themes/newscorpau-news-dna/dist/stylesheets/css-news-desktop-lazy.css?v=15";
# newscorpau.brand = "news";
# newscorpau.vidora = "https://www.news.com.au/wp-content/themes/newscorpau-news-dna/dist/javascripts/js-vidora-client.js?v=15";
# newscorpau.c3poJS = "https://www.news.com.au/wp-content/themes/newscorpau-news-dna/dist/javascripts/js-c3po-bundle.js?v=15";
#    </script>
#    <script>
#     newscorpau.videoPlayerJS = "https://resourcesssl.newscdn.com.au/cs/video/vjs/stable/build/player.js";
# newscorpau.VideoPlayerCSS = "https://www.news.com.au/wp-content/themes/newscorpau-news-dna/dist/stylesheets/css-video-fonts.css";
#    </script>
#    <script>
#     newscorpau.weatherJS = "https://www.news.com.au/wp-content/themes/newscorpau-news-dna/dist/javascripts/js-weather.js?v=15";
#    </script>
#    <script async="" src="https://www.news.com.au/wp-content/themes/newscorpau-news-dna/dist/javascripts/js-critical-desktop.js?v=15">
#    </script>
#   </div>
#   <script async="" charset="utf-8" src="https://pixel.zprk.io/v5/pixeljs/3zcdIyo2Tk.js?timewithTz=2021-09-09T09%3A37%3A46.056Z&amp;country=au&amp;newsconnectId=&amp;fpid=8f2f4d033a7d858aa867b2ad6196a493" type="text/javascript">
#   </script>
#   <iframe src="https://70cf75018df8c46be7ccca63b908fa9d.safeframe.googlesyndication.com/safeframe/1-0-38/html/container.html" style="visibility: hidden; display: none;">
#   </iframe>
#   <div id="ad-out-of-page" style="display: none;">
#    <div id="google_ads_iframe_/5129/ndm.news/news/national/victoria/crime_5__container__" style="border: 0pt none;">
#    </div>
#   </div>
#   <iframe class="aamIframeLoaded" id="destination_publishing_iframe_newscorpau_0" name="destination_publishing_iframe_newscorpau_0_name" sandbox="allow-scripts allow-same-origin" src="https://newscorpau.demdex.net/dest5.html?d_nsid=0#https%3A%2F%2Fwww.news.com.au" style="display: none; width: 0px; height: 0px;" title="Adobe ID Syncing iFrame">
#   </iframe>
#   <iframe frameborder="0" height="0" id="ncg_cookie_8587-1631180267333" src="//ncg.tags.news.com.au/prod/ncg/cookie.html" width="0">
#   </iframe>
#   <iframe height="0" id="lsframe" src="https://cdn-gl.imrworldwide.com/novms/html/ls.html" style="display: none;" width="0">
#   </iframe>
#  </body>
# </html>

# %%
# date_time = soup.find('body').find('div', class_='header_date-bar_now').text
# print(date_time)

# %%
#headline_list = []

headlines = soup.find_all('a', class_='storyblock_title_link')

for headline in headlines:
    if len(headline)<5: 
        title= headline.text.strip()
        #headline_list.append(title)
    print(title)
# Out:
# Police called to Porsche driver’s home
# Family’s plea after horror stabbing
# Doctor traumatised by fatal home birth
# ‘Frightening’ shooting at suburban Macca’s
# Cops fine ‘all adults’ at synagogue gathering
# Caravan park murder accused ‘distressed’
# Multiple suspects in bookshop murder: Court
# Fatal stabbing in caravan park: cops
# Mum’s shock death after homebirth
# Anti-vax leader is a reality TV flop
# Blow in warring exes defamation trial
# Cruel act to snatch Maccas meal: cops
# Home-birth midwives deny claims after death
# Kids karate teacher’s sick acts on student
# Seven arrests in suspected bikie murder
# New twist in woman’s suspected murder
# New push to solve brutal schoolgirl murder
# 46 arrests, machetes seized: cops
# Cops hit in frightening ‘hate crime’
# Vocal anti-vaxxer’s shock court move
# Woman’s gesture to alleged gang murderer
# Axe attackers of hero dad still on the run
# ‘No excuse’: Footy star fined for driving
# Hunt for rapist after 30 years of freedom
# Man’s sick words before walking path rapes
# ‘Rot in hell’: Family interrupts murder hearing
# Protesters’ chilling posts targeting cops
# Driver charged with death of footballer
# Missing woman’s boyfriend charged
# Protesters police wish to speak to

# %%
#link_list = []

results = soup.find_all('h4', class_='storyblock_title')

for result in results:
    link = result.a['href']
    #link_list.append(link)
    print(link)
# Out:
# https://www.news.com.au/national/victoria/crime/cops-called-to-richard-puseys-fitzroy-home-over-loud-music-and-yelling/news-story/1d0ecfcc09ac3073977ecf7818422330
# https://www.news.com.au/national/victoria/crime/daughter-of-stabbed-man-chris-lyons-starts-fundraiser/news-story/781e1ed20da9deef841c0ab613d90a0e
# https://www.news.com.au/national/victoria/courts-law/treating-caroline-lovell-after-fatal-homebirth-traumatic-for-doctor/news-story/98f3f02d54c2ea18fd6552d396076ce5
# https://www.news.com.au/national/victoria/courts-law/cruz-noonan-jailed-for-shooting-at-police-at-sunbury-mcdonalds/news-story/1b9d8b6f7e787499fdf4c7fca5ec95b8
# Police in Melbourne have become the target of a frightening hate crime as tension mounts at authorities during the state’s sixth lockdown.
# A former reality TV wannabe turned vocal anti-vaxxer has made a shock decision in court after she was granted bail for allegedly inciting protests.
# A man charged with murder of a 15-year-old boy  in a horror fight against 11 people has been granted bail after an offer by a woman he has never met in person.
# Three men who attacked a Melbourne dad with an axe when he heroically jumped the fence to save his neighbour are still on the run months later.
# A star footballer has been fined for seven driving offences, with a magistrate saying the Collingwood player offered no excuse.
# A new appeal has been launched to track down a rapist who has enjoyed 30 years of freedom after a sickening attack on a mum of five.
# A predator who grabbed women from walking paths in one of Melbourne’s ritziest suburbs made sick statements during his horrifying acts.
# The family of a missing woman allegedly murdered by her boyfriend have used his first court hearing to speak directly to him with one demand.
# Anti-lockdown protesters have taken their fight against police online, with chilling messages including the personal details of individual officers surfacing.
# A driver who police allege left a young footballer for dead on the side of the road in the middle of the night has been charged.
# Detectives have laid a murder charge against the boyfriend of a Melbourne woman who was last seen at a Woolworths store in April.
# Police have released photos of eight anti-lockdown protesters they wish to speak to about incidents at a rally in Melbourne.

# %%
#image_elem = soup.find("img", class_="responsive-img_img storyblock_img").get("src")

# page = soup.find_all("section", attrs:{class_='site-content', )

# images = page.find("span", class_="storyblock_meta").get("src")

# print(images)

for item in soup.find_all('img'):
    image = item.get("src")
    #print(item['src'])
    print(image)
# Out:
# https://www.news.com.au/wp-content/themes/newscorpau-news-dna/dist/images/logos/news.svg
# https://content.api.news/v3/images/bin/0b64ac1ca0b2109f51683fe455ffd98a
# https://content.api.news/v3/images/bin/df0c1be156bed6c7a961cbb7f69903e4
# https://content.api.news/v3/images/bin/cc7d8170fa0f2f5e0a0388f20f76bdbb
# https://content.api.news/v3/images/bin/9c3b902c7ff6149cdb2308df4bc4a98c
# https://content.api.news/v3/images/bin/6fcb313d047f271828b4f53d76fda5ae
# https://content.api.news/v3/images/bin/9fb055b7b5aa0b9b4e17584623285fb7
# https://content.api.news/v3/images/bin/1e45c777f49d08589b8b7ae6c574f606
# https://content.api.news/v3/images/bin/998047ed2c98a61f5a30ea7c1bd61ac5
# https://content.api.news/v3/images/bin/f519e32b4dc7fca42ce9ce73cf0fae91
# https://content.api.news/v3/images/bin/0d8110e7a30981099ea14aef3239dff9
# https://content.api.news/v3/images/bin/341ffbf2b03c958a5ec1f1a807bc696f
# https://content.api.news/v3/images/bin/3dbe98f9765af665a1e80d4b91e1fe4f
# https://content.api.news/v3/images/bin/a3c0e9ba551b4048c7f7359e438322ce
# https://content.api.news/v3/images/bin/cb25dc7ccd06cf7ab5e016e861f3156f
# https://content.api.news/v3/images/bin/a11344ffd2a5f95334db439b43d25566
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.news.com.au/wp-content/themes/newscorpau-news-dna/dist/images/logos/news.svg

# %%
data = {
        "headline": title,
        "url": link,
        "description": about,
        "image": image
     }

print(data)
# Out:
# {'headline': 'Protesters police wish to speak to', 'url': 'https://www.news.com.au/national/victoria/crime/melbourne-antilockdown-protesters-sought-by-police-pictured/news-story/d1b5eb8ad45b8829f531e58b257b13a9', 'description': 'Police have released photos of eight anti-lockdown protesters they wish to speak to about incidents at a rally in Melbourne.', 'image': 'https://www.news.com.au/wp-content/themes/newscorpau-news-dna/dist/images/logos/news.svg'}
